# %% [markdown]
# ### Assignment 1

# %%
raw_text = " PyThOn is AweSome and badword programming! "

# %%
final_raw = raw_text.strip()
final_raw
# Out:
# 'PyThOn is AweSome and badword programming!'

# %%
length = len(final_raw)
length
# Out:
# 42

# %%
final = final_raw.lower()
final
# Out:
# 'python is awesome and badword programming!'

# %%
cleaned_text = final.replace("badword", "powerful")
cleaned_text
# Out:
# 'python is awesome and powerful programming!'

# %%
extracted = cleaned_text[31:42]
extracted
# Out:
# 'programming'

# %%
cleaned_text[-12:-1]
# Out:
# 'programming'

# %%
print(f"Original length:{length}, cleaned text: {cleaned_text}, Extracted word: {extracted}")
# Out:
# Original length:42, cleaned text: python is awesome and powerful programming!, Extracted word: programming

# %% [markdown]
# ### Assignment 3 - "The Salary Calculator"

# %%
def calculate_salary(hours, hourly_rate):
    gross = hours* hourly_rate
    if gross > 5000:
        gross = gross - 0.1 * gross
        final_net_salary = gross
    else:
        gross = gross - 0.05 * gross
        final_net_salary = gross
        print(f" John worked {hours}hrs @ {hourly_rate}") 
        return print(f" Jane worked {hours}hrs @ {hourly_rate}") 
calculate_salary(40, 100)
calculate_salary(60, 200)
# Out:
#  John worked 40hrs @ 100
#  Jane worked 40hrs @ 100

# %%
calculate_salary(60, 200)
reprint(f"John worked {hours}hrs @ {hourly_rate},\njane worked {hours}hrs @ {hourly_rate}")
# Out:
# The Final Net Salary is 3800.0
#  worked 40hrs @ 100

# %%
def calculate_salary(hours, hourly_rate):
    gross = hours * hourly_rate

    if gross > 5000:
        final_net_salary = gross - 0.1 * gross
    else:
        final_net_salary = gross - 0.05 * gross
        print(f"Final Net Salary: {final_net_salary}")
        
    
calculate_salary(40, 100)  # John
# Out:
# Final Net Salary: 3800.0

# %%
 print(f"john: {hours}, Rate: {hourly_rate} \njane: {hours}, Rate: {hourly_rate}" )

calculate_salary(40, 100)  # John
calculate_salary(60, 200)  # Jane
